# %% [markdown]
# # Raw Data
#
# - Target:
#   - Compensation: http://appsso.eurostat.ec.europa.eu/nui/setupDownloads.do
# - Features:
#   - Education: https://ec.europa.eu/eurostat/web/products-datasets/-/trng_lfs_02
#   - Population: https://ec.europa.eu/eurostat/web/products-datasets/-/tps00001
#   - R&D expenditure: https://ec.europa.eu/eurostat/web/products-datasets/-/t2020_20
#   - ...
#
# ## Compensation
#
# - The zip file contains 25 tables
# - It contains many empty tables and duplicates
# - I used the tables below
#   - nama_10_lp_ulc_1_Data.csv: Compensation of employees per hour worked (Euro)
#   - nama_10_lp_ulc_2_Data.csv: Compensation per employee (Euro)
#   - nama_10_lp_ulc_10_Data.csv: Real labour productivity per person (Index, 2015=100)
# - Compensation per hour worked and compensation per employee are highly correlated (0.99)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import locale

# %%
data_raw_dir = '../data/raw'

def atof(value):
    if value == ':':
        return None
    return locale.atof(value.replace(',', ''))

def nantonone(flag):
    if flag == 'nan':
        return None
    return flag

def truncate(geo, limit=20):
    return (geo[:limit] + '..') if len(geo) > limit else geo

geos_to_exclude = [
    'European Union - 27 countries (from 2020)',
    'European Union - 28 countries (2013-2020)',
    'European Union - 15 countries (1995-2004)',
    'Euro area (EA11-1999, EA12-2001, EA13-2007, EA15-2008, EA16-2009, EA17-2011, EA18-2014, EA19-2015)',
    'Euro area - 19 countries  (from 2015)',
    'Euro area - 12 countries (2001-2006)']

country_name_dict = {
    'Germany (until 1990 former territory of the FRG)': 'Germany'
}
    
def normalize_country_name(name):
    if name in country_name_dict:
        return country_name_dict[name]
    else:
        return name

dfs = []
overview = []
for i in range(1,26):
    filename = f'nama_10_lp_ulc_{i}_Data.csv'
    df = pd.read_csv(f'{data_raw_dir}/{filename}')
    df = df[~df['GEO'].isin(geos_to_exclude)]
    df['TIME'] = df['TIME'].astype(int)
    df['GEO'] = df['GEO'].apply(normalize_country_name)
    df['Value'] = df['Value'].apply(atof)
    df['Flag and Footnotes'] = df['Flag and Footnotes'].apply(nantonone)
    dfs.append(df)
    
    na_item = ''.join(df['NA_ITEM'].unique())
    unit = ''.join(df['UNIT'].unique())
    value_null_rate = df['Value'].isna().mean().round(4) * 100
    flag_null_rate = df['Flag and Footnotes'].isna().mean().round(4) * 100
    overview.append({
        'filename': filename,
        'NA_ITEM': na_item,
        'UNIT': unit,
        'value_null_rate': value_null_rate,
        'flag_null_rate': flag_null_rate,
    })
overview_df = pd.DataFrame(overview)
display(overview_df)
display(overview_df['NA_ITEM'].unique().tolist())
# Out:
#                       filename                                      NA_ITEM  \
# 0    nama_10_lp_ulc_1_Data.csv    Compensation of employees per hour worked
# 1    nama_10_lp_ulc_2_Data.csv                    Compensation per employee
# 2    nama_10_lp_ulc_3_Data.csv  Nominal labour productivity per hour worked
# 3    nama_10_lp_ulc_4_Data.csv       Nominal labour productivity per person
# 4    nama_10_lp_ulc_5_Data.csv          Real labour productivity per person
# 5    nama_10_lp_ulc_6_Data.csv    Compensation of employees per hour worked
# 6    nama_10_lp_ulc_7_Data.csv                    Compensation per employee
# 7    nama_10_lp_ulc_8_Data.csv  Nominal labour productivity per hour worked
# 8    nama_10_lp_ulc_9_Data.csv       Nominal labour productivity per person
# 9   nama_10_lp_ulc_10_Data.csv          Real labour productivity per person
# 10  nama_10_lp_ulc_11_Data.csv    Compensation of employees per hour worked
# 11  nama_10_lp_ulc_12_Data.csv                    Compensation per employee
# 12  nama_10_lp_ulc_13_Data.csv  Nominal labour productivity per hour worked
# 13  nama_10_lp_ulc_14_Data.csv       Nominal labour productivity per person
# 14  nama_10_lp_ulc_15_Data.csv          Real labour productivity per person
# 15  nama_10_lp_ulc_16_Data.csv    Compensation of employees per hour worked
# 16  nama_10_lp_ulc_17_Data.csv                    Compensation per employee
# 17  nama_10_lp_ulc_18_Data.csv  Nominal labour productivity per hour worked
# 18  nama_10_lp_ulc_19_Data.csv       Nominal labour productivity per person
# 19  nama_10_lp_ulc_20_Data.csv          Real labour productivity per person
# 20  nama_10_lp_ulc_21_Data.csv    Compensation of employees per hour worked
# 21  nama_10_lp_ulc_22_Data.csv                    Compensation per employee
# 22  nama_10_lp_ulc_23_Data.csv  Nominal labour productivity per hour worked
# 23  nama_10_lp_ulc_24_Data.csv       Nominal labour productivity per person
# 24  nama_10_lp_ulc_25_Data.csv          Real labour productivity per person
#
#                                UNIT  value_null_rate  flag_null_rate
# 0                              Euro            10.00           83.53
# 1                              Euro             7.35           81.76
# 2                              Euro           100.00          100.00
# 3                              Euro           100.00          100.00
# 4                              Euro           100.00          100.00
# 5                   Index, 2010=100           100.00          100.00
# 6                   Index, 2010=100           100.00          100.00
# 7                   Index, 2010=100           100.00          100.00
# 8                   Index, 2010=100           100.00          100.00
# 9                   Index, 2010=100             7.06           80.29
# 10                  Index, 2015=100           100.00          100.00
# 11                  Index, 2015=100           100.00          100.00
# 12                  Index, 2015=100           100.00          100.00
# 13                  Index, 2015=100           100.00          100.00
# 14                  Index, 2015=100             7.06           79.41
# 15                National currency            10.00           83.53
# 16                National currency             7.35           81.76
# 17                National currency           100.00          100.00
# 18                National currency           100.00          100.00
# 19                National currency           100.00          100.00
# 20  Purchasing power standard (PPS)            17.94           86.76
# 21  Purchasing power standard (PPS)            15.59           85.00
# 22  Purchasing power standard (PPS)           100.00          100.00
# 23  Purchasing power standard (PPS)           100.00          100.00
# 24  Purchasing power standard (PPS)           100.00          100.00
# ['Compensation of employees per hour worked',
#  'Compensation per employee',
#  'Nominal labour productivity per hour worked',
#  'Nominal labour productivity per person',
#  'Real labour productivity per person']

# %%
compensation_per_hour_df = dfs[0]
compensation_per_hour_df.rename(columns={'Value': 'Compensation of employees per hour worked (Euro)'}, inplace=True)

compensation_per_employee_df = dfs[1]
compensation_per_employee_df.rename(columns={'Value': 'Compensation per employee (Euro)'}, inplace=True)

productivity_per_person_df = dfs[9]
productivity_per_person_df.rename(columns={'Value': 'Real labour productivity per person (Index, 2015=100)'}, inplace=True)

# %%
df = compensation_per_hour_df[['TIME', 'GEO', 'Compensation of employees per hour worked (Euro)']]
df_to_merge = compensation_per_employee_df[['TIME', 'GEO', 'Compensation per employee (Euro)']]

df = df.merge(df_to_merge, on=['TIME', 'GEO'])
df_to_merge = productivity_per_person_df[['TIME', 'GEO', 'Real labour productivity per person (Index, 2015=100)']]

productivity_df = df.merge(df_to_merge, on=['TIME', 'GEO'])
productivity_df.head()
# Out:
#    TIME      GEO  Compensation of employees per hour worked (Euro)  \
# 0  2010  Belgium                                              34.3
# 1  2011  Belgium                                              35.1
# 2  2012  Belgium                                              36.2
# 3  2013  Belgium                                              37.2
# 4  2014  Belgium                                              37.6
#
#    Compensation per employee (Euro)  \
# 0                           49054.8
# 1                           50593.5
# 2                           52178.2
# 3                           53452.5
# 4                           53965.2
#
#    Real labour productivity per person (Index, 2015=100)
# 0                                              100.0
# 1                                              100.4
# 2                                              100.7
# 3                                              101.4
# 4                                              102.6

# %%
plt.figure(figsize=(12,8))
sns.lineplot(data=productivity_df, x='TIME', y='Compensation of employees per hour worked (Euro)', hue='GEO')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.lineplot(data=productivity_df, x='TIME', y='Compensation per employee (Euro)', hue='GEO')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.lineplot(data=productivity_df, x='TIME', y='Real labour productivity per person (Index, 2015=100)', hue='GEO')
plt.show()

# %%
column = 'Compensation of employees per hour worked (Euro)'
temp = productivity_df[~productivity_df[column].isnull()]
times = sorted(temp['TIME'].unique())
start, end = times[0], times[-1]
agg_first = temp.groupby(by=['GEO']).first().reset_index()
agg_last = temp.groupby(by=['GEO']).last().reset_index()
productivity_agg = agg_first.merge(agg_last, on=['GEO'], suffixes=('_start', '_last'))
productivity_agg['diff'] = productivity_agg.apply(lambda row: row[f'{column}_last'] - row[f'{column}_start'],axis=1)
productivity_agg['productivity_rank'] = productivity_agg['diff'].rank(ascending=False).astype(int)
sorted_agg = productivity_agg.sort_values(by='diff', ascending=False)
display(sorted_agg.head(5))
display(sorted_agg.tail(5))
# Out:
#             GEO  TIME_start  \
# 13      Iceland        2010
# 29  Switzerland        2010
# 18   Luxembourg        2010
# 10      Germany        2010
# 0       Austria        2010
#
#     Compensation of employees per hour worked (Euro)_start  \
# 13                                               20.4
# 29                                               38.9
# 18                                               38.7
# 10                                               26.2
# 0                                                25.1
#
#     Compensation per employee (Euro)_start  \
# 13                                 31185.9
# 29                                 62068.8
# 18                                 58910.9
# 10                                 35409.2
# 0                                  39392.8
#
#     Real labour productivity per person (Index, 2015=100)_start  TIME_last  \
# 13                                              100.0                 2019
# 29                                              100.0                 2018
# 18                                              100.0                 2018
# 10                                              100.0                 2019
# 0                                               100.0                 2019
#
#     Compensation of employees per hour worked (Euro)_last  \
# 13                                               41.4
# 29                                               49.3
# 18                                               46.9
# 10                                               33.7
# 0                                                31.7
#
#     Compensation per employee (Euro)_last  \
# 13                                60998.9
# 29                                76494.7
# 18                                70617.9
# 10                                44963.9
# 0                                 48275.2
#
#     Real labour productivity per person (Index, 2015=100)_last  diff  \
# 13                                              109.0           21.0
# 29                                              102.4           10.4
# 18                                              101.3            8.2
# 10                                              105.8            7.5
# 0                                               103.5            6.6
#
#     productivity_rank
# 13                  1
# 29                  2
# 18                  3
# 10                  4
# 0                   5
#          GEO  TIME_start  \
# 27     Spain        2010
# 23  Portugal        2010
# 3    Croatia        2010
# 4     Cyprus        2010
# 11    Greece        2010
#
#     Compensation of employees per hour worked (Euro)_start  \
# 27                                               19.1
# 23                                               11.0
# 3                                                 8.3
# 4                                                14.8
# 11                                               13.4
#
#     Compensation per employee (Euro)_start  \
# 27                                 31449.5
# 23                                 20863.9
# 3                                  16462.0
# 4                                  25954.5
# 11                                 26073.1
#
#     Real labour productivity per person (Index, 2015=100)_start  TIME_last  \
# 27                                              100.0                 2019
# 23                                              100.0                 2019
# 3                                               100.0                 2019
# 4                                               100.0                 2019
# 11                                              100.0                 2019
#
#     Compensation of employees per hour worked (Euro)_last  \
# 27                                               20.3
# 23                                               11.9
# 3                                                 9.2
# 4                                                14.5
# 11                                               11.6
#
#     Compensation per employee (Euro)_last  \
# 27                                32680.2
# 23                                22017.0
# 3                                 16828.1
# 4                                 25148.8
# 11                                21971.6
#
#     Real labour productivity per person (Index, 2015=100)_last  diff  \
# 27                                              106.5            1.2
# 23                                              104.4            0.9
# 3                                               112.7            0.9
# 4                                               102.2           -0.3
# 11                                               94.1           -1.8
#
#     productivity_rank
# 27                 27
# 23                 28
# 3                  29
# 4                  30
# 11                 31

# %%
countries_sorted_by_productivity = productivity_agg.sort_values(by='diff', ascending=False)['GEO']

fig, axes = plt.subplots(1, 2, figsize=(20, 6))
sns.lineplot(data=df[df['GEO'].isin(countries_sorted_by_productivity[:5])], x='TIME', y=column, hue='GEO', ax=axes[0])
axes[0].set_title('Growing counties')
sns.lineplot(data=df[df['GEO'].isin(countries_sorted_by_productivity[-5:])], x='TIME', y=column, hue='GEO', ax=axes[1])
axes[1].set_title('Not growing counties')
plt.show()

# %%
column = 'Compensation of employees per hour worked (Euro)'
temp = productivity_df[~productivity_df[column].isnull()]
# productivity_agg = temp.groupby(by=['GEO']).last().reset_index()
productivity_agg = temp.groupby(['GEO'])[column].mean().reset_index()
productivity_agg['productivity_rank'] = productivity_agg[column].rank(ascending=False).astype(int)
sorted_agg = productivity_agg.sort_values(by=column, ascending=False)
display(sorted_agg.head(5))
display(sorted_agg.tail(5))
# Out:
#             GEO  Compensation of employees per hour worked (Euro)  \
# 21       Norway                                         47.970000
# 29  Switzerland                                         46.900000
# 18   Luxembourg                                         42.533333
# 6       Denmark                                         38.010000
# 1       Belgium                                         37.066667
#
#     productivity_rank
# 21                  1
# 29                  2
# 18                  3
# 6                   4
# 1                   5
#           GEO  Compensation of employees per hour worked (Euro)  \
# 16     Latvia                                              7.32
# 17  Lithuania                                              7.20
# 22     Poland                                              6.48
# 24    Romania                                              4.92
# 2    Bulgaria                                              4.46
#
#     productivity_rank
# 16                 27
# 17                 28
# 22                 29
# 24                 30
# 2                  31

# %% [markdown]
# ## Education
#
# - **Hypothesis**: Educated people make more money
#   - Education and productivity are correlated (0.34)
#
# ### Note
#
# - Weak correlation: 0.1 - 0.3
# - Moderate correlation: 0.3 - 0.5
# - Strong correlation: 0.5 - 1.0

# %%
education_df = pd.read_csv(f'{data_raw_dir}/trng_lfs_02.tsv', delimiter='\t')
education_df.head()
# Out:
#   unit,isced11,sex,age,geo\time  2018    2017    2016   2015     2014   2013   \
# 0          PC,ED0-2,F,Y18-24,AT  64.6    63.8    61.6   60.7    60.2 b  69.8
# 1          PC,ED0-2,F,Y18-24,BE  72.2   64.5 b   60.0   54.8    58.2 b  55.6
# 2          PC,ED0-2,F,Y18-24,BG  48.6    48.1    45.3   46.1    48.8 b  49.0
# 3          PC,ED0-2,F,Y18-24,CH  86.1    83.6    79.7   80.6    78.8 b  80.8
# 4          PC,ED0-2,F,Y18-24,CY  44.3    40.2   50.1 u  61.1   57.9 bu  51.9
#
#    2012   2011    2010     2009    2008   2007     2006    2005    2004
# 0  68.3   66.9    67.0     64.9    62.5   59.5    58.8 b   60.7   59.3 b
# 1  53.8   53.8    55.8     54.6   52.0 b  52.6    53.2 b   49.2   62.5 b
# 2  47.5   52.4    51.6     50.5    50.6   54.2    47.7 b   42.1    45.1
# 3  81.3   81.9   77.0 b    74.2    77.4   80.0     75.7    73.2    74.6
# 4  45.0   37.9    31.2   28.9 bu  25.0 u  41.7   26.3 bu  20.7 u   28.6

# %%
from iso3166 import countries
import re

country_code_dict = {
    'EL': 'GR',
    'UK': 'GB'
}

def country_code_to_name(code):
    if code in country_code_dict:
        code = country_code_dict[code]
    try:
        return countries.get(code).name
    except KeyError:
        return None
    
country_name_dict = {
    'United Kingdom of Great Britain and Northern Ireland': 'United Kingdom',
}
    
def normalize_country_name(name):
    if name in country_name_dict:
        return country_name_dict[name]
    else:
        return name

flag_dict = {
    ':': 'not available',
    'p': 'provisional',
    'b': 'break in time series',
    'd': 'definition differs',
    'c': 'conditional',
    'e': 'estimated',
}

def extract_flags(p_str):
    flag = None
    for char in flag_dict:
        if char in p_str:
            flag = flag_dict[char]
            break
    return flag

def preprocess(df):
    # Rename
    columns_to_rename = {c: c.rstrip() for c in df.columns if c.endswith(' ')}
    raw_base_column = [c for c in df.columns if c.endswith('\\time')][0] # e.g. 'unit,isced11,sex,age,geo\\time'
    base_column = raw_base_column.replace('\\time', '')
    columns_to_rename[raw_base_column] = base_column
    df.rename(columns=columns_to_rename, inplace=True)
    
    # Unpivot
    df = df.melt(id_vars=base_column, var_name='year', value_name='value')
    
    # Split
    columns_to_split = base_column.split(',')
    df[columns_to_split] = df[base_column].str.split(',', expand=True)
    df.drop(columns=[base_column], inplace=True)
    
    # Normalize country name
    df.rename(columns={'geo': 'GEO'}, inplace=True)
    df['GEO'] = df['GEO'].apply(country_code_to_name)
    df['GEO'] = df['GEO'].apply(normalize_country_name)
    
    # Extract flags
    df['flags'] = df['value'].apply(lambda p_str: extract_flags(p_str))
    df['value'] = df['value'].apply(lambda p_str: re.sub('[^\d\.]', '', p_str))
    df['value'] = df['value'].replace('', None)
    
    # Convert data types
    df['year'] = df['year'].astype(int)
    df['value'] = pd.to_numeric(df['value'], errors='coerce')

    return df

# %%
education_df = preprocess(education_df)
education_df.head()
# Out:
#    year  value unit isced11 sex     age          GEO flags
# 0  2018   64.6   PC   ED0-2   F  Y18-24      Austria  None
# 1  2018   72.2   PC   ED0-2   F  Y18-24      Belgium  None
# 2  2018   48.6   PC   ED0-2   F  Y18-24     Bulgaria  None
# 3  2018   86.1   PC   ED0-2   F  Y18-24  Switzerland  None
# 4  2018   44.3   PC   ED0-2   F  Y18-24       Cyprus  None

# %%
temp = education_df[education_df['age'] == 'Y18-24']
education_agg = temp.groupby(['GEO','year'])['value'].mean().reset_index()
education_agg = education_agg.groupby(['GEO'])['value'].mean().reset_index()
education_agg['education_rank'] = education_agg['value'].rank(ascending=False).astype(int)
education_agg.head()
# Out:
#         GEO      value  education_rank
# 0   Austria  55.740000              13
# 1   Belgium  48.940476              26
# 2  Bulgaria  46.524444              28
# 3   Croatia  54.408889              18
# 4    Cyprus  39.391667              33

# %%
merged_df = productivity_agg[['GEO', 'productivity_rank']].merge(education_agg[['GEO', 'education_rank']], on='GEO')
merged_df.sort_values(by='productivity_rank')
# Out:
#                GEO  productivity_rank  education_rank
# 21          Norway                  1               7
# 29     Switzerland                  2              19
# 18      Luxembourg                  3               3
# 6          Denmark                  4               1
# 1          Belgium                  5              26
# 20     Netherlands                  6               4
# 9           France                  7              15
# 13         Iceland                  8              17
# 10         Germany                  9              12
# 8          Finland                 10               9
# 0          Austria                 11              13
# 28          Sweden                 12               5
# 14         Ireland                 13              31
# 30  United Kingdom                 14              30
# 15           Italy                 15              16
# 27           Spain                 16              14
# 26        Slovenia                 17               2
# 4           Cyprus                 18              33
# 19           Malta                 19              34
# 11          Greece                 20              29
# 23        Portugal                 21              21
# 7          Estonia                 22              11
# 25        Slovakia                 23              10
# 5          Czechia                 24              20
# 3          Croatia                 25              18
# 12         Hungary                 26              24
# 16          Latvia                 27              23
# 17       Lithuania                 28               8
# 22          Poland                 29               6
# 24         Romania                 30              27
# 2         Bulgaria                 31              28

# %%
merged_df.corr()
# Out:
#                    productivity_rank  education_rank
# productivity_rank           1.000000        0.333111
# education_rank              0.333111        1.000000

# %%
productivity_df
# Out:
#      TIME      GEO  Compensation of employees per hour worked (Euro)  \
# 0    2010  Belgium                                              34.3
# 1    2011  Belgium                                              35.1
# 2    2012  Belgium                                              36.2
# 3    2013  Belgium                                              37.2
# 4    2014  Belgium                                              37.6
# ..    ...      ...                                               ...
# 335  2015   Serbia                                               NaN
# 336  2016   Serbia                                               NaN
# 337  2017   Serbia                                               NaN
# 338  2018   Serbia                                               NaN
# 339  2019   Serbia                                               NaN
#
#      Compensation per employee (Euro)  \
# 0                             49054.8
# 1                             50593.5
# 2                             52178.2
# 3                             53452.5
# 4                             53965.2
# ..                                ...
# 335                               NaN
# 336                               NaN
# 337                               NaN
# 338                               NaN
# 339                               NaN
#
#      Real labour productivity per person (Index, 2015=100)
# 0                                                100.0
# 1                                                100.4
# 2                                                100.7
# 3                                                101.4
# 4                                                102.6
# ..                                                 ...
# 335                                                NaN
# 336                                                NaN
# 337                                                NaN
# 338                                                NaN
# 339                                                NaN
#
# [340 rows x 5 columns]

# %% [markdown]
# ## Population

# %%
population_df = pd.read_csv(f'{data_raw_dir}/tps00001.tsv', delimiter='\t')
population_df.head()
# Out:
#   indic_de,geo\time     2008      2009      2010      2011      2012   \
# 0            JAN,AD    83137     84484     84082    78115 b    78115
# 1            JAN,AL  2958266   2936355   2918674   2907361   2903008
# 2            JAN,AM  3230086   3237976   3249482   3262650   3274285
# 3            JAN,AT  8307989   8335003   8351643   8375164   8408121
# 4            JAN,AZ  8629900   8896900   8997586   9111078   9235085
#
#       2013      2014      2015      2016      2017      2018      2019
# 0    76246         :         :     71732         :    74794 e    76177
# 1  2897770   2892394   2885796   2875592   2876591   2870324   2862427
# 2  3026878         :   3010598   2998577   2986151   2972732   2965269
# 3  8451860   8507786   8584926   8700471   8772865   8822267   8858775
# 4  9356483   9477119   9593038   9705643   9809981   9898085   9981457

# %%
population_df = preprocess(population_df)
population_df.head()
# Out:
#    year    value indic_de         GEO flags
# 0  2008    83137      JAN     Andorra  None
# 1  2008  2958266      JAN     Albania  None
# 2  2008  3230086      JAN     Armenia  None
# 3  2008  8307989      JAN     Austria  None
# 4  2008  8629900      JAN  Azerbaijan  None

# %%
population_df['indic_de'].unique()
# Out:
# array(['JAN'], dtype=object)

# %%
plt.figure(figsize=(12,8))
sns.lineplot(data=population_df, x='year', y='value', hue='GEO')
plt.show()

# %% [markdown]
# ## R&D expenditure

# %%
rd_df = pd.read_csv(f'{data_raw_dir}/t2020_20.tsv', delimiter='\t')
rd_df.drop(columns=['TARGET '], inplace=True)
rd_df.head()
# Out:
#   unit,indic_eu,geo\time 1990  1991   1992  1993  1994    1995    1996   \
# 0     PC_GDP,T2020_20,AT    :     :      :     :     :   1.53 e  1.58 e
# 1     PC_GDP,T2020_20,BA    :     :      :     :     :       :       :
# 2     PC_GDP,T2020_20,BE    :     :      :     :     :    1.65    1.74
# 3     PC_GDP,T2020_20,BG    :     :      :     :     :    0.43   0.42 b
# 4     PC_GDP,T2020_20,CH    :     :   2.38     :     :       :    2.45
#
#     1997   1998   ...  2009    2010   2011    2012   2013    2014   2015   \
# 0  1.66 e  1.73   ...   2.6   2.73 e  2.67   2.91 e  2.95   3.08 e  3.05
# 1      :      :   ...     :       :      :    0.27   0.32    0.26      :
# 2   1.81   1.84   ...     2    2.06   2.17    2.28   2.33    2.37   2.43
# 3   0.47   0.48   ...  0.49    0.57   0.53     0.6   0.64    0.79   0.95
# 4      :      :   ...     :       :      :    3.19      :       :   3.37
#
#    2016   2017    2018
# 0  3.12   3.05   3.17 p
# 1     :      :       :
# 2  2.52   2.66   2.76 p
# 3  0.77   0.74    0.76
# 4     :   3.29       :
#
# [5 rows x 30 columns]

# %%
rd_df = preprocess(rd_df)
rd_df.head()
# Out:
#    year  value    unit  indic_eu                     GEO          flags
# 0  1990    NaN  PC_GDP  T2020_20                 Austria  not available
# 1  1990    NaN  PC_GDP  T2020_20  Bosnia and Herzegovina  not available
# 2  1990    NaN  PC_GDP  T2020_20                 Belgium  not available
# 3  1990    NaN  PC_GDP  T2020_20                Bulgaria  not available
# 4  1990    NaN  PC_GDP  T2020_20             Switzerland  not available

# %%
plt.figure(figsize=(12,8))
sns.lineplot(data=rd_df, x='year', y='value', hue='GEO')
plt.show()
